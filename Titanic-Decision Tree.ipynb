# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,MinMaxScaler,StandardScaler,Normalizer
import numpy as np
import csv,os
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\subhajit.choudhury\Desktop\machine learning\kaggle\titanic\train.csv')
testdf = pd.read_csv(r'C:\Users\subhajit.choudhury\Desktop\machine learning\kaggle\titanic\test.csv')
predictionsfile = r'C:\Users\subhajit.choudhury\Desktop\machine learning\kaggle\titanic\submission_5.csv'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#df[df['Survived']==1]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.dropna(subset=['Embarked'])
le= LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
#df['Cabin'] = le.fit_transform(df['Cabin'].astype(str))
df['Embarked'] = le.fit_transform(df['Embarked'])
df.Age.fillna(df.Age.mean(),inplace=True)
df = df.drop(['Name','Ticket','Cabin','PassengerId'],axis=1)

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
# df.hist(figsize=(10,6))
# plt.show()

# %%
# class_cols = list(df.drop(['Survived','Age','Fare'],axis=1).columns)
# cont_cols = ['Age','Fare']

# %%
# for col in class_cols:
#     df.groupby(['Survived',col]).size().unstack().plot(kind='bar', stacked=True, figsize=(5,2))

# %%
# fig, ax = plt.subplots()
# df.plot.scatter('Fare','Age',c='Survived',colormap='Spectral',figsize=(15,3),ax = ax)
# plt.show()

# %%
corr = df.corr()
# plt.figure(figsize=(20,10))
# plt.matshow(corr)
# plt.xticks(range(len(corr.columns)), corr.columns);
# plt.yticks(range(len(corr.columns)), corr.columns);
# plt.show()
sns.heatmap(corr,annot=True)
plt.show()

# %%
x = df.drop('Survived',axis=1)
y = df['Survived']

# %%
# scaler = MinMaxScaler(feature_range=(0,1))
scaler = StandardScaler()
# scaler = Normalizer()
x_scaled = scaler.fit_transform(x)

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y)
# scoredict = {}
# #options = np.linspace(0.1, 0.5, 5, endpoint=True)
# options = range(1,10)
# for opt in options:
#     tree = DecisionTreeClassifier(criterion='gini',max_features=None,max_depth=4,min_samples_split=4,min_samples_leaf=opt)
#     scores = cross_val_score(tree,x,y,cv=10,scoring='roc_auc')
#     score = scores.mean()
#     scoredict[opt] = score
# plt.plot(scoredict.keys(),scoredict.values())

# %%
# max_depth = range(1,10)
# min_samples_split = np.linspace(0.1, 1.0, 10, endpoint=True) 
# min_samples_leaf = np.linspace(0.1, 0.5, 5, endpoint=True)
# criterion_options = ["gini","entropy"]
# max_features = ['auto', 'sqrt', 'log2']

# %%
# param_grid = dict(criterion = criterion_options, 
#                   max_depth = max_depth, 
#                   min_samples_split = min_samples_split, min_samples_leaf = min_samples_leaf, 
#                   max_features = max_features)
# grid = GridSearchCV(tree,param_grid,cv=10,scoring="accuracy",verbose=2)
# #grid = RandomizedSearchCV(tree,param_grid,cv=10,scoring="accuracy")
# grid.fit(x,y)
# print(grid.best_score_)
# print(grid.best_params_)

# %%
tree=DecisionTreeClassifier(criterion = 'gini', max_features=None, max_depth=4, min_samples_split=4, min_samples_leaf=6)
tree.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=6, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
testdf_bck = testdf
# testdf.head()

# %%
#testdf.isnull().sum()

# %%
passengerlist = testdf.PassengerId
#testdf = testdf.dropna(subset=['Embarked'])
#testdf = testdf.dropna(subset=['Fare'])
le= LabelEncoder()
testdf['Sex'] = le.fit_transform(testdf['Sex'])
#testdf['Cabin'] = le.fit_transform(testdf['Cabin'].astype(str))
testdf['Embarked'] = le.fit_transform(testdf['Embarked'])
testdf.Age.fillna(testdf.Age.mean(),inplace=True)
testdf.Fare.fillna(testdf.Fare.mean(),inplace=True)
testdf = testdf.drop(['Name','Ticket','Cabin','PassengerId'],axis=1)

# %%
testdf_scaled = scaler.fit_transform(testdf)
predictions = tree.predict(testdf)

# %%
with open(predictionsfile,'w') as writefile:
    writer = csv.writer(writefile)
    writer.writerow(['PassengerId','Survived'])
    for i in range(len(passengerlist)):
        row = [passengerlist[i],predictions[i]]
        writer.writerow(row)

# %%
testdf['Survived'] = predictions

# %%
df.groupby('Survived').count()
# Out:
#           Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# Survived
# 0            549  549  549    549    549   549       549
# 1            340  340  340    340    340   340       340

# %%
testdf.groupby('Survived').count()
# Out:
#           Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# Survived
# 0            272  272  272    272    272   272       272
# 1            146  146  146    146    146   146       146

# %%
# fig, ax = plt.subplots()
# df.plot.scatter('Age','Sex',c='Survived',colormap='coolwarm',figsize=(20,2), ax = ax)
# plt.show()
fig = plt.figure(figsize=(18,4))
#fig = plt.figure(figsize=plt.figaspect(0.5))
ax = fig.add_subplot(121, projection='3d')
ax.scatter(df.Age, df.Sex, df.Pclass, c=df.Survived, cmap='PiYG', linewidth=0.5, s=20, edgecolors='w')
ax.set_xlabel('Age')
ax.set_ylabel('Sex')
ax.set_zlabel('Pclass')
ax = fig.add_subplot(122, projection='3d')
ax.scatter(testdf.Age, testdf.Sex, testdf.Pclass, c=testdf.Survived, cmap='PiYG', linewidth=0.5, s=25, edgecolors='w')
ax.set_xlabel('Age')
ax.set_ylabel('Sex')
ax.set_zlabel('Pclass')
plt.show()

# %%
# fig, ax = plt.subplots()
# testdf.plot.scatter('Age','Sex',c='Survived',colormap='coolwarm',figsize=(20,2), ax = ax)
# plt.show()

# %%
testdf['Name'] = testdf_bck['Name']
testdf[testdf['Survived']==1]
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked  Survived  \
# 4         3    0  22.00000      1      1   12.2875         2         1
# 6         3    0  30.00000      0      0    7.6292         1         1
# 8         3    0  18.00000      0      0    7.2292         0         1
# 12        1    0  23.00000      1      0   82.2667         2         1
# 14        1    0  47.00000      1      0   61.1750         2         1
# 15        2    0  24.00000      1      0   27.7208         0         1
hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6                                 Connolly, Miss. Kate
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15       del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 18                        Ilmakangas, Miss. Ida Livija
# 22                Flegenheim, Mrs. Alfred (Antoinette)
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26                        Ostby, Miss. Helene Ragnhild
# 32            Dean, Mrs. Bertram (Eva Georgetta Light)
# 36                                 Roth, Miss. Sarah A
# 37                                  Cacic, Miss. Manda
# 43               Corbett, Mrs. Walter H (Irene Colvin)
# 44    Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 48     Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 49      Coutts, Mrs. William (Winnie Minnie" Treanor)"
# 52                       Hocking, Miss. Ellen Nellie""
# 53                          Fortune, Miss. Ethel Flora
# 59                         Chaudanson, Miss. Victorine
# 63                        Bradley, Miss. Bridget Delia
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# 66                             Burns, Miss. Mary Delia
# 69                 Fortune, Mrs. Mark (Mary McDougald)
# 70                           Mulvihill, Miss. Bertha E
# 72                      Nieminen, Miss. Manta Josefina
# 74                                Geiger, Miss. Amalie
# 77   Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 79                              Doyle, Miss. Elizabeth
# 80                                Boulos, Master. Akar
# ..                                                 ...
# 333              Nakid, Mrs. Said (Waika Mary" Mowad)"
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 345                        Abelseth, Miss. Karen Marie
# 349                             Walcroft, Miss. Nellie
# 350       Greenfield, Mrs. Leo David (Blanche Strouse)
# 354            Dean, Miss. Elizabeth Gladys Millvina""
# 356     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 359  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...
# 361            Mallet, Mrs. Albert (Antoinette Magnin)
# 362       Ware, Mrs. John James (Florence Louise Long)
# 364       Harder, Mrs. George Achilles (Dorothy Annan)
# 368            Gibson, Mrs. Leonard (Pauline C Boeson)
# 371                          Wilson, Miss. Helen Alice
# 374              Dodge, Mrs. Washington (Ruth Vidaver)
# 375                           Bowen, Miss. Grace Scott
# 376                                  Kink, Miss. Maria
# 382                         Risien, Mrs. Samuel (Emma)
# 383                McNamee, Mrs. Neal (Eileen O'Leary)
# 385                                 Herman, Miss. Kate
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 400                            Bonnell, Miss. Caroline
# 402                     Gibson, Miss. Dorothy Winifred
# 408                    Riordan, Miss. Johanna Hannah""
# 409                          Peacock, Miss. Treasteall
# 410                             Naughton, Miss. Hannah
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 414                       Oliva y Ocana, Dona. Fermina
#
# [146 rows x 9 columns]
